# %%
import yfinance as yf

ap=["MSFT", "AAPL"]
data = yf.Tickers(ap)
dataDF = data.history(period= "1Mo" , start= "2010-01-1" ,end= "2023-01-01" )
dataDF
# Out:
# [*********************100%***********************]  2 of 2 completed
#                  Close             Dividends             High              \
#                   AAPL        MSFT      AAPL MSFT        AAPL        MSFT
# Date
# 2010-01-04    6.496295   23.572369       0.0  0.0    6.511169   23.686612
# 2010-01-05    6.507525   23.579985       0.0  0.0    6.544255   23.686613
# 2010-01-06    6.404016   23.435280       0.0  0.0    6.533328   23.671384
# 2010-01-07    6.392176   23.191559       0.0  0.0    6.435280   23.381966
# 2010-01-08    6.434673   23.351498       0.0  0.0    6.435281   23.519055
# ...                ...         ...       ...  ...         ...         ...
# 2022-12-23  131.477127  237.614105       0.0  0.0  132.035499  237.753450
# 2022-12-27  129.652435  235.852386       0.0  0.0  131.028433  237.813164
# 2022-12-28  125.674026  233.433731       0.0  0.0  130.649535  238.599474
# 2022-12-29  129.233658  239.883438       0.0  0.0  130.101127  240.789188
# ...

# %%
import matplotlib.pyplot as plt
dataDF["Close"].plot()
plt.show()

# %%
download=yf.download(["MSFT", "aapl", "F"],period= "1mo",start= "1980-01-1" ,end= "2023-1-1" )['Adj Close']
# Out:
# [*********************100%***********************]  3 of 3 completed

# %% [markdown]
# pip install yfinance
# pip install matplotlib

# %%
download
# Out:
#                   AAPL          F        MSFT
# Date
# 1980-01-02         NaN   0.243910         NaN
# 1980-01-03         NaN   0.243910         NaN
# 1980-01-04         NaN   0.241990         NaN
# 1980-01-07         NaN   0.240069         NaN
# 1980-01-08         NaN   0.244871         NaN
# ...                ...        ...         ...
# 2022-12-23  131.477127  10.440842  237.614105
# 2022-12-27  129.652435  10.293789  235.852386
# 2022-12-28  125.674019  10.064015  233.433731
# 2022-12-29  129.233658  10.606278  239.883453
# 2022-12-30  129.552719  10.688997  238.699020
#
# [10843 rows x 3 columns]

# %%
download.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10843 entries, 1980-01-02 to 2022-12-30
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    10603 non-null  float64
#  1   F       10843 non-null  float64
#  2   MSFT    9277 non-null   float64
# dtypes: float64(3)
# memory usage: 338.8 KB

# %%
import yfinance as yf
nom=("data_us22.csv")
download=yf.download(["^GSPC", "AOS", "AMD", "AKAM", "MO", "BKI", "BP", "CYYNF", "DFS", "F", "GWRE", "HD", "OSTK", "RDWR", "SENS", "SQ", "TWLO", "V", "XNET", "GE", "AAPL", "BA", "SGMO", "gold", "pfe", "NVDA", "BABA", "TSLA", "TLT"],period= "1mo",start= "1970-01-1" ,end= "2023-4-1", interval= "1mo" )
download.to_csv(nom)
# Out:
# [*********************100%***********************]  29 of 29 completed
